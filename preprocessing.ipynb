# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# %%
# Split data 9:1 for training:eval. Format the text by combining Title + Body to give the model context.
INPUT_FILE = "data/raw_bmw_data.jsonl"
TRAIN_FILE = "data/train.json"
VAL_FILE = "data/val.json"

def load_data(filepath):
    data = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))
    return pd.DataFrame(data)

def preprocess_text(row):
    """Combines title and text with a separator."""
    # Clean up excessive whitespace.
    title = row['title'].strip()
    text = row['text'].strip()
    return f"Title: {title}\nContent: {text}"

def main():
    if not os.path.exists(INPUT_FILE):
        print("Raw data not found. Run scrape.py first.")
        return

    df = load_data(INPUT_FILE)
    print(f"Loaded {len(df)} raw documents.")

    # Preprocessing
    df['processed_text'] = df.apply(preprocess_text, axis=1)
    
    # Split
    train_df, val_df = train_test_split(df, test_size=0.1, random_state=42)
    
    # Convert to HuggingFace dataset friendly dict format
    train_data = [{"text": text} for text in train_df['processed_text']]
    val_data = [{"text": text} for text in val_df['processed_text']]

    # Save
    with open(TRAIN_FILE, 'w', encoding='utf-8') as f:
        json.dump(train_data, f, indent=2)
        
    with open(VAL_FILE, 'w', encoding='utf-8') as f:
        json.dump(val_data, f, indent=2)

    print(f"Saved {len(train_data)} training samples and {len(val_data)} validation samples.")

if __name__ == "__main__":
    main()
# Out:
# Loaded 20 raw documents.
# Saved 18 training samples and 2 validation samples.

# %%
train_df, val_df = train_test_split(a, test_size=0.1, random_state=42)

# %%
val_df
# Out:
#                                                   url  \
# 0   https://www.press.bmwgroup.com/global/article/...
# 17  https://www.press.bmwgroup.com/global/article/...
#
#                                                 title date_str  \
# 0   Technical specifications of the MINI John Coop...
# 17  BMW Group and Solid Power take next step in AS...
#
#                                                  text  \
# 0   Julian KischBMW GroupTel: +49-151-601-38072sen...
# 17  Bernhard EdererBMW GroupTel: +49-89-382-28556F...
#
#                                        processed_text
# 0   Title: Technical specifications of the MINI Jo...
# 17  Title: BMW Group and Solid Power take next ste...

# %%
val_data = [{"text": text} for text in val_df['processed_text']]

# %%
val_data
# Out:
# [{'text': 'Title: Technical specifications of the MINI John Cooper Works Convertible, valid from 11/2024.\nContent: Julian KischBMW GroupTel: +49-151-601-38072send an e-mail Julian KischBMW Group In the attachment you will find the technical specifications of the\n  MINI John Cooper Works Convertible, valid from 11/2024. Here you can see the webcast of the BMW Group Keynote at the Japan Mobility Show 2025.'},
#  {'text': 'Title: BMW Group and Solid Power take next step in ASSB development path: new partner Samsung SDI joins the effort\nContent: Bernhard EdererBMW GroupTel: +49-89-382-28556Fax: +49-89-382-20626send an e-mail Bernhard EdererBMW Group Munich.Since 2022, the BMW Group and Solid Power,\n  Inc. (Nasdaq: SLDP) have intensified their activities for the\n  development of all-solid-state battery (ASSB) technology through their\n  technology transfer agreement. The latest milestone was the\n  integration of Solid Power’s large-format pure ASSB cells into a BMW\n  i7 technology test vehicle. As of October 2025, Samsung SDI joins the efforts to\n  pursue development and validation of the ASSB technology in the\n  automotive field. The new collaboration marks a key step towards ASSB\n  technology, bringing together the complementary expertise of three\n  industry leaders.Under this arrangement, Solid Power will supply sulfide-based\n  solid electrolyte to Samsung SDI, which Samsung SDI will integrate\n  into separator and/or catholyte and use to build cells, in each case\n  subject to achievement of technical requirements.These cells\n  will be evaluated based on performance parameters and requirements to\n  be agreed between Samsung SDI and BMW Group. Ultimately, Solid Power,\n  Samsung SDI, and BMW aim to develop and supply ASSB cells for\n  integration into a next generation of evaluation vehicles. “We are excited to partner with Samsung SDI and BMW\n  to progress the development of all-solid-state batteries,” said John\n  Van Scoter, President and CEO of Solid Power. “Our solid electrolyte\n  technology is designed for stability and conductivity, and by working\n  closely with global leaders in automotive and battery innovation, we\n  strive to bring ASSB technology closer to widespread adoption.” "Technological competitiveness in batteries would ultimately\n  lead to innovation in electric vehicles," said Stella Joo-Young\n  Go, Executive Vice President of ASSB Commercialization Team at Samsung\n  SDI. "Samsung SDI will work closely with great global partners\n  like BMW and Solid Power to take the lead in commercializing ASSB." Martin Schuster, Vice President Battery Cell\n  and Cell Module at the BMW Group, says: “With Samsung SDI joining our\n  partnership with Solid Power, we gain significant momentum on our path\n  advancing the development of new battery cell technologies. This\n  global collaboration is another proof point of our overarching goal:\n  to be always in a position to offer our customers state of the art\n  battery technology.”The partners believe in the potential of genuine ASSB\n  technology, and the promise of higher energy density combined with\n  increased safety compared to today’s technologies by replacing liquid\n  electrolytes with solid materials.With increased energy density, longer vehicle ranges can be\n  achieved without having to accept disadvantages in terms of weight of\n  the overall storage system.The BMW Group and Solid Power have been cooperating since 2016\n  through an extended “Joint Development Agreement,” which was supported\n  by a BMW Group investment in Solid Power in May 2021 as part of a\n  financing round. At the end of 2022, BMW and Solid Power agreed to\n  further deepen their partnership. BMW will operate a solid-state cell\n  prototype line at the CMCC in Parsdorf, on the basis of a research and\n  development license and with Solid Power\'s experience and expertise. Since 2008, the BMW Group has been consistently\n  building up its competence in the field of battery cell technology.\n  Since 2019, this know-how has been pooled at the BMW Group\'s Battery\n  Cell Competence Center (BCCC) in Munich. The BCCC covers the entire\n  value chain, from research and development to battery cell design to producibility. In order to be able to quickly and efficiently\n  implement innovations in the field of battery cell technology, the BMW\n  Group cooperates in a network of around  ...
